# %%
import wbdata
import datetime
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
import numpy as np

# %%
# Fetch country list from World Bank data
countries = wbdata.get_country(country_id=None)
country_names = [country['name'] for country in countries]

# Fetch population data
start_date = datetime.datetime(2000, 1, 1)
end_date = datetime.datetime(2021, 1, 1)
indicator = {"SP.POP.TOTL": "Population"}

# %%
country_id = "USA"
wbdata.get_data('SP.POP.TOTL')
# Out:
# [{'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2022',
#   'value': 720839314,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2021',
#   'value': 702977106,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2020',
#   'value': 685112979,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2019',
# ...

# %%
def predict_population(years, values, future_years=10):
    # Use simple linear regression for prediction
    x = np.array(years)
    y = np.array(values)
    slope, intercept = np.polyfit(x, y, 1)
    future_years = np.array(range(years[-1] + 1, years[-1] + future_years + 1))
    return future_years, slope * future_years + intercept

def plot_population(country_name):
    years, values = fetch_population_data(country_name)
    future_years, future_values = predict_population(years, values)

    plt.figure(figsize=(12,6))
    plt.plot(years, values, 'o-', label='Actual Data')
    plt.plot(future_years, future_values, 'x--', label='Projected Data', color='red')
    plt.title(f'Population of {country_name}')
    plt.xlabel('Year')
    plt.ylabel('Population')
    plt.legend()
    plt.grid(True)
    plt.show()

# Create interactive widgets
country_selector = widgets.Dropdown(options=country_names, description='Country:')
interactive_plot = widgets.interactive(plot_population, country_name=country_selector)

# Display widget
display(interactive_plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/djdaniels/code/active_workspace/jupyter/workspace/population_estimates.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/Users/djdaniels/code/active_workspace/jupyter/workspace/population_estimates.ipynb#W3sZmlsZQ%3D%3D?line=20'>21</a>     plt.show()
#      <a href='vscode-notebook-cell:/Users/djdaniels/code/active_workspace/jupyter/workspace/population_estimates.ipynb#W3sZmlsZQ%3D%3D?line=22'>23</a> # Create interactive widgets
# ---> <a href='vscode-notebook-cell:/Users/djdaniels/code/active_workspace/jupyter/workspace/population_estimates.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a> country_selector = widgets.Dropdown(options=country_names, description='Country:')
# ...
